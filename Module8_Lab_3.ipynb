# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhithamatlapudi/FMML-Lab-sessions/blob/main/Module8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-28 11:00:31--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   108MB/s    in 0.6s
#
# 2023-05-28 11:00:32 (108 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22297  1512.03308v2  One of the core problems in statistical models...  stat
# 26859  1701.00951v1  Point matching refers to the process of findin...    cs
# 35181  cs/0005013v1  Description Logics (DLs) are a family of knowl...    cs
# 22405  1606.00118v1  In genome-wide interaction studies, to detect ...  stat
# 32508   1311.0914v1  The kernel support vector machine (SVM) is one...    cs
# ...             ...                                                ...   ...
# 34524  1701.03492v1  Financial institutions have to screen their tr...    cs
# 40680   1309.4999v1  It is essential to find solar predictive metho...    cs
# 21370  1801.06689v1  Recent advances in deep learning have allowed ...    cs
# 24611   1409.4095v1  We introduce a method based on the deflectomet...    cs
# 12883  1802.06627v1  Deep neural networks have been shown to be vul...    cs
#
#                                                    title  year  \
# 22297               Guaranteed inference in topic models  2015
# 26859  A Concave Optimization Algorithm for Matching ...  2017
# 35181  Practical Reasoning for Very Expressive Descri...  2000
# 22405  Gene-Gene association for Imaging Genetics Dat...  2016
# 32508  A Divide-and-Conquer Solver for Kernel Support...  2013
# ...                                                  ...   ...
# 34524  Scalable, Trie-based Approximate Entity Extrac...  2017
# 40680  Bayesian rules and stochastic models for high ...  2013
# 21370  Learning model-based strategies in simple envi...  2018
# 24611  Cavlectometry: Towards Holistic Reconstruction...  2014
# 12883  Robustness of Rotation-Equivariant Networks to...  2018
#
#                                                 keywords
# 22297  [statistical, estimation, posterior, distribut...
# 26859  [transformation, correspondences, following, a...
# 35181  [description, knowledge, representation, forma...
# 22405  [interaction, interactions, nucleotide, polymo...
# 32508  [classification, computation, bottleneck, part...
# ...                                                  ...
# 34524  [financial, institutions, transactions, affili...
# 40680  [essential, predictive, massively, renewable, ...
# 21370  [artificial, performance, generalizable, strat...
# 24611  [introduce, deflectometry, principle, reconstr...
# 12883  [vulnerable, adversarial, perturbations, predi...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22297    [statistical, estimation, posterior, distribut...
# 26859    [transformation, correspondences, following, a...
# 35181    [description, knowledge, representation, forma...
# 22405    [interaction, interactions, nucleotide, polymo...
# 32508    [classification, computation, bottleneck, part...
#                                ...
# 111      [recurrent, architecture, sequences, discourse...
# 26357    [exploiting, reconstruction, extensively, vari...
# 936      [artificial, occasionally, quantitative, struc...
# 15981    [generating, synthetic, languages, validation,...
# 3848     [kiperwasser, attention, dependency, thoroughl...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8886 words.
# Out of those 4557 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="05fc3e18-8ad6-4b3f-bf6d-801d82f3a530" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("05fc3e18-8ad6-4b3f-bf6d-801d82f3a530")) {                    Plotly.newPlot(                        "05fc3e18-8ad6-4b3f-bf6d-801d82f3a530",                        [{"x":["especially","posterior","guarantee","behaviors","inference","distribution","introduce","consequence","particularly","allocation","discussions","posteriori","estimation","algorithm","approaches","demonstrate","extensive","individual","statistical","properties","guarantees","intractable","experiments","including","dirichlet","approximate","convergence","important","guaranteed","theoretical","attractive","nonlinear","bottleneck","cardinality","dimension","formulation","robustness","overlapping","efficiency","outperforms","objective","assignment","following","furthermore","optimization","resulting","transformation","experimental","converted","correspondence","computation","partially","correspondences","eliminating","efficiently","minimization","knowledge","formalisms","procedures","applications","practical","hierarchies","representation","decidability","satisfiability","expressive","characterised","transitive","techniques","constraints","problematical","inclusion","computationally","additionally","complexity","functional","restrictions","investigate","optimisation","obtaining","implementations","reasoning","implementation","performance","description","association","effective","relationship","synthesized","therefore","covariance","polymorphisms","sensitive","operators","interactions","correlation","resampling","statistic","nonparametric","basically","contaminated","interaction","intensive","canonical","classical","nucleotide","influence","suggested","classification","subproblem","solutions","partitioned","identified","appropriately","converges","subproblems","independently","partition","prediction","clustering","coordinate","initialize","multilevel","theoretically","extending","regression","projection","sacrificing","experimentally","randomized","desirable","efficient","stochastic","iterations","regularization","algorithms","illustrate","preserved","variables","computing","iteration","benchmark","incremental","independence","ambiguities","likelihood","incorporated","parameters","diversity","decomposing","applicability","optimality","multivariate","dependencies","accurately","available","separation","mathematical","improvement","generalized","motivates","information","integrate","underlying","assumption","component","exploitation","additional","permutation","application","independent","framework","development","assumptions","estimator","probability","thresholded","personalized","personalizing","heterogeneity","personalization","interacting","interested","abandonment","scenarios","structure","population","contribution","incredible","capability","navigation","potentially","validation","technology","discriminative","recognition","potential","multiscale","technique","resolution"],"y":[125,42,28,37,224,225,325,22,83,34,11,12,214,831,439,587,174,104,164,218,53,27,577,224,26,104,117,347,34,163,18,49,25,12,64,91,105,29,141,274,176,25,95,172,333,160,67,386,9,31,143,43,21,14,187,62,360,12,32,391,124,7,412,2,16,25,5,6,358,135,2,8,102,62,242,41,16,150,19,42,41,114,117,879,63,23,242,68,14,159,24,0,51,50,90,76,7,5,16,2,4,91,23,22,105,0,52,34,510,6,133,8,40,10,20,11,36,22,218,137,24,7,2,42,31,107,46,9,46,32,28,394,112,22,99,587,59,12,141,128,41,201,26,28,3,77,25,213,41,4,50,19,31,59,65,276,25,62,142,70,12,666,46,129,69,105,26,132,13,255,130,554,117,63,29,170,1,12,2,4,4,17,23,0,101,383,37,68,2,45,38,41,60,63,91,361,156,8,236,140],"type":"bar"},{"x":["especially","posterior","guarantee","behaviors","infer ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4557,), (4557, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3846153846153845);'>Technical</span> <span style=''>Note</span> <span style=''>Bias</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.37931034482758624);'>Quantification</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Stability</span> <br/><br/><span style=''>Research</span> <span style=''>on</span> <span style=''>bias</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>has</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generally</span> <span style=''>been</span> <span style='background-color:rgba(0, 255, 0, 0.43589743589743585);'>concerned</span> <span style=''>with</span> <span style=''>the</span> <span style=''>impact</span> <span style=''>of</span> <span style=''>bias</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3854166666666667);'>predictive</span> <span style=''>accuracy</span> <span style=''>We</span> <span style=''>believe</span> <span style=''>that</span> <span style=''>there</span> <span style=''>are</span> <span style=''>other</span> <span style=''>factors</span> <span style=''>that</span> <span style=''>should</span> <span style=''>also</span> <span style=''>play</span> <span style=''>a</span> <span style=''>role</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.4277777777777777);'>evaluation</span> <span style=''>of</span> <span style=''>bias</span> <span style=''>One</span> <span style=''>such</span> <span style=''>factor</span> <span style=''>is</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>stability</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>in</span> <span style=''>other</span> <span style=''>words</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>repeatability</span> <span style=''>of</span> <span style=''>the</span> <span style=''>results</span> <span style=''>If</span> <span style=''>we</span> <span style=''>obtain</span> <span style=''>two</span> <span style=''>sets</span> <span style=''>of</span> <span style=''>data</span> <span style=''>from</span> <span style=''>the</span> <span style=''>same</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>phenomenon</span> <span style=''>with</span> <span style=''>the</span> <span style=''>same</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>underlying</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>then</span> <span style=''>we</span> <span style=''>would</span> <span style=''>like</span> <span style=''>our</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>to</span> <span style=''>induce</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximately</span> <span style=''>the</span> <span style=''>same</span> <span style=''>concepts</span> <span style=''>from</span> <span style=''>both</span> <span style=''>sets</span> <span style=''>of</span> <span style=''>data</span> <span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduces</span> <span style=''>a</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>quantifying</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>stability</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style=''>measure</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255,  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Auto</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>associative</span> <span style=''>models</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Principal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>component</span> <span style=''>analysis</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>manifolds</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projection</span> <span style=''>pursuit</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>auto</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>associative</span> <span style=''>models</span> <span style=''>are</span> <span style=''>proposed</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>candidates</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalization</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Principal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Component</span> <span style=''>Analysis</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>these</span> <span style=''>models</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dedicated</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>dataset</span> <span style=''>by</span> <span style=''>a</span> <span style=''>manifold</span> <span style=''>Here</span> <span style=''>the</span> <span style=''>word</span> <span style=''>manifold</span> <span style=''>refers</span> <span style=''>to</span> <span style=''>the</span> <span style=''>topology</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximating</span> <span style=''>manifold</span> <span style=''>is</span> <span style=''>built</span> <span style=''>by</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projection</span> <span style=''>pursuit</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>At</span> <span style=''>each</span> <span style=''>step</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimension</span> <span style=''>of</span> <span style=''>the</span> <span style=''>manifold</span> <span style=''>is</span> <span style=''>incremented</span> <span style=''>Some</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>are</span> <span style=''>provided</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>we</span> <span style=''>can</span> <span style=''>show</span> <span style=''>that</span> <span style=''>at</span> <span style=''>each</span> <span style=''>step</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>the</span> <span style=''>mean</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>residuals</span> <span style=''>norm</span> <span style=''>is</span> <span style=''>not</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increased</span> <span style=''>Moreover</span> <span style=''>it</span> <span style=' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Discrete</span> <span style=''>symbolic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Boltzmann</span> <span style=''>sampling</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuous</span> <span style=''>neural</span> <span style=''>dynamics</span> <span style=''>Gradient</span> <span style=''>Symbolic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Computation</span> <br/><br/><span style=''>Gradient</span> <span style=''>Symbolic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Computation</span> <span style=''>is</span> <span style=''>proposed</span> <span style=''>as</span> <span style=''>a</span> <span style=''>means</span> <span style=''>of</span> <span style=''>solving</span> <span style=''>discrete</span> <span style=''>global</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>problems</span> <span style=''>using</span> <span style=''>a</span> <span style=''>neurally</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>plausible</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuous</span> <span style='background-color:rgba(255, 0, 0, 0.44278606965174133);'>stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dynamical</span> <span style=''>system</span> <span style=''>Gradient</span> <span style=''>symbolic</span> <span style=''>dynamics</span> <span style=''>involves</span> <span style=''>two</span> <span style=''>free</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>that</span> <span style=''>must</span> <span style=''>be</span> <span style=''>adjusted</span> <span style=''>as</span> <span style=''>a</span> <span style=''>function</span> <span style=''>of</span> <span style=''>time</span> <span style=''>to</span> <span style=''>obtain</span> <span style=''>the</span> <span style=''>global</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>maximizer</span> <span style=''>at</span> <span style=''>the</span> <span style=''>end</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computation</span> <span style=''>We</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>summary</span> <span style=''>of</span> <span style=''>what</span> <span style=''>is</span> <span style=''>known</span> <span style=''>about</span> <span style=''>the</span> <span style=''>GSC</span> <span style=''>dynamics</span> <span style=''>for</span> <span style=''>special</span> <span style=''>cases</span> <span style=''>of</span> <span style=''>settings</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>and</span> <span style=''>also</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>establish</span> <span style=''>that</span> <span style=''>there</span> <span style=''>is</span> <span style=''>a</span> <span style=''>schedule</span> <span style=''>for</span> <span style=''>the</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>for</span> <span style=''>which</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>convergence</span> <span style=''>to</span> <span style=''>the</span> <span style=''>correct</span> <span style=''>answer</span> <span style=''>occurs</span> <span style=''>with</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>These</span> <span style=''>results</span> <span style=''>put</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirical</span> <span style=''>results</span> <span style=''>already</span> <span style=''>ob ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style=''>spatial</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selectivity</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>across</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditions</span> <span style=''>with</span> <span style=''>fMRI</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Researchers</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>neuroimaging</span> <span style=''>mostly</span> <span style=''>use</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>activation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>coordinates</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formulate</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypotheses</span> <span style=''>Instead</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>to</span> <span style=''>use</span> <span style=''>the</span> <span style=''>full</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>images</span> <span style=''>to</span> <span style=''>define</span> <span style=''>regions</span> <span style=''>of</span> <span style=''>interest</span> <span style=''>(ROIs)</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>presents</span> <span style=''>two</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>transfer</span> <span style=''>learning</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>transfer</span> <span style=''>that</span> <span style=''>are</span> <span style=''>compared</span> <span style=''>upon</span> <span style=''>their</span> <span style=''>ability</span> <span style=''>to</span> <span style=''>identify</span> <span style=''>the</span> <span style=''>common</span> <span style=''>patterns</span> <span style=''>between</span> <span style=''>brain</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>activation</span> <span style=''>maps</span> <span style=''>related</span> <span style=''>to</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style=''>tasks</span> <span style=''>We</span> <span style=''>provide</span> <span style=''>some</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>preliminary</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>quantification</span> <span style=''>of</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>similarities</span> <span style=''>and</span> <span style=''>show</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>transfer</span> <span style=''>makes</span> <span style=''>it</span> <span style=''>possible</span> <span style=''>to</span> <span style=''>set</span> <span style=''>a</span> <span style=''>spatial</span> <span style=''>scale</span> <span style=''>yielding</span> <span style=''>ROIs</span> <span style=''>that</span> <span style=''>are</span> <span style=''>more</span> <span style=''>specific</span> <span style=''>to</span> <span style=''>the</span> <span style=''>context</span> <span style=''>of</span> <span style=''>interest</span> <span style=''>than</span> <span style=''>with</span> <span style=''>transfer</span> <span style=''>learning</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>transfer</span> <span style=''>outlines</span> <span style=''>well</span> <span styl ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.08945686900958466)
# 	knowledge (0.12779552715654952)
# 	segmentation (0.06815761448349308)
# 	representation (0.14625488107916224)
# 	experimental (0.13702520411785588)
# 	information (0.2364217252396166)
# 	detection (0.11537096201632943)
# 	recognition (0.12815051473198438)
# 	different (0.2648207312744054)
# 	convolutional (0.13702520411785588)
#
# Some Statistics words are:
# 	variables (0.1437216338880484)
# 	theoretical (0.15179021684316693)
# 	algorithm (0.3908219868885527)
# 	statistical (0.15632879475542108)
# 	stochastic (0.14624306606152296)
# 	estimation (0.18456883509833585)
# 	distribution (0.19919314170448815)
# 	dimensional (0.19465456379223398)
# 	inference (0.20827029752899648)
# 	regression (0.18709026727181038)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="c45c5554-4e23-466e-b711-c31ab48b98ca" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c45c5554-4e23-466e-b711-c31ab48b98ca")) {                    Plotly.newPlot(                        "c45c5554-4e23-466e-b711-c31ab48b98ca",                        [{"x":["especially","posterior","guarantee","behaviors","inference","distribution","introduce","consequence","particularly","allocation","discussions","posteriori","estimation","algorithm","approaches","demonstrate","extensive","individual","statistical","properties","guarantees","intractable","experiments","including","dirichlet","approximate","convergence","important","guaranteed","theoretical","attractive","nonlinear","bottleneck","cardinality","dimension","formulation","robustness","overlapping","efficiency","outperforms","objective","assignment","following","furthermore","optimization","resulting","transformation","experimental","converted","correspondence","computation","partially","correspondences","eliminating","efficiently","minimization","knowledge","formalisms","procedures","applications","practical","hierarchies","representation","decidability","satisfiability","expressive","characterised","transitive","techniques","constraints","problematical","inclusion","computationally","additionally","complexity","functional","restrictions","investigate","optimisation","obtaining","implementations","reasoning","implementation","performance","description","association","effective","relationship","synthesized","therefore","covariance","polymorphisms","sensitive","operators","interactions","correlation","resampling","statistic","nonparametric","basically","contaminated","interaction","intensive","canonical","classical","nucleotide","influence","suggested","classification","subproblem","solutions","partitioned","identified","appropriately","converges","subproblems","independently","partition","prediction","clustering","coordinate","initialize","multilevel","theoretically","extending","regression","projection","sacrificing","experimentally","randomized","desirable","efficient","stochastic","iterations","regularization","algorithms","illustrate","preserved","variables","computing","iteration","benchmark","incremental","independence","ambiguities","likelihood","incorporated","parameters","diversity","decomposing","applicability","optimality","multivariate","dependencies","accurately","available","separation","mathematical","improvement","generalized","motivates","information","integrate","underlying","assumption","component","exploitation","additional","permutation","application","independent","framework","development","assumptions","estimator","probability","thresholded","personalized","personalizing","heterogeneity","personalization","interacting","interested","abandonment","scenarios","structure","population","contribution","incredible","capability","navigation","potentially","validation","technology","discriminative","recognition","potential","multiscale","technique","resolution","threefold","recognize","assistive","distinctiveness","wayfinding","appearance","interpret","misclassification","perception","activating","evaluating","similarity","convolutional","buildings","parsimonious","processing","conditional","languages","structured","communities","estimates","mislabeled","implement","confidence","dependency","aggressive","proposing","introduced","perceptron","probabilistic","alternatives","correctness","regarding","precision","correctly","penalization","exponents","exemplify","shrinkage","bernstein","hierarchical","evaluation","empirical","simulated","dimensional","nonconvex","functions","continuous","maximization","simultaneously","coefficients","processes","different","morphological","compa ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	polymorphisms
# 	nucleotide
# 	abandonment
# 	uncountable
# 	actigraphy
# 	respiration
# 	cigarette
# 	tibshirani
# 	reseeding
# 	diffusing
# 	unequally
# 	consolidation
# 	refitting
# 	representatives
# 	parsimony
# 	byproduct
# 	anonymous
# 	regressions
# 	inappropriately
# 	confounding
# Some words which never appear in Statistics papers:
# 	formalisms
# 	decidability
# 	characterised
# 	problematical
# 	incredible
# 	assistive
# 	distinctiveness
# 	wayfinding
# 	buildings
# 	obligations
# 	attractiveness
# 	equalized
# 	propositional
# 	postulates
# 	fragments
# 	specificities
# 	depicting
# 	homography
# 	keyframes
# 	harmonics

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.055581018730712e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.755
